# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Flatten
from tensorflow.keras.optimizers import SGD
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /Users/qin/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# 载入数据集
mnist = tf.keras.datasets.mnist
# 载入训练集和测试集
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# 对训练集和测试集的数据进行归一化处理，有助于提升模型训练速度
x_train, x_test = x_train / 255.0, x_test / 255.0
# 把训练集和测试集的标签转为独热编码
y_train = tf.keras.utils.to_categorical(y_train,num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test,num_classes=10)

# 模型定义，model1使用Dropout
# Dropout(0.4)表示隐藏层40%神经元不工作
model1 = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(units=200,activation='tanh'),
        Dropout(0.4),
        Dense(units=100,activation='tanh'),
        Dropout(0.4),
        Dense(units=10,activation='softmax')
        ])

# 在定义一个一模一样的模型用于对比测试，model2不使用Dropout
# Dropout(0)表示隐藏层所有神经元都工作，相当于没有Dropout
model2 = Sequential([
        Flatten(input_shape=(28, 28)),
        Dense(units=200,activation='tanh'),
        Dropout(0),
        Dense(units=100,activation='tanh'),
        Dropout(0),
        Dense(units=10,activation='softmax')
        ])

# sgd定义随机梯度下降法优化器
# loss='categorical_crossentropy'定义交叉熵代价函数
# metrics=['accuracy']模型在训练的过程中同时计算准确率
sgd = SGD(0.2)
model1.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model2.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 传入训练集数据和标签训练模型
# 周期大小为30（把所有训练集数据训练一次称为训练一个周期）
epochs = 30
# 批次大小为32（每次训练模型传入32个数据进行训练）
batch_size=32
# validation_data设置验证集数据
# 先训练model1
history1 = model1.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test,y_test))
# 再训练model2
history2 = model2.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, validation_data=(x_test,y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 4s 62us/sample - loss: 0.4170 - accuracy: 0.8737 - val_loss: 0.2087 - val_accuracy: 0.9370
# Epoch 2/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.2808 - accuracy: 0.9165 - val_loss: 0.1627 - val_accuracy: 0.9498
# Epoch 3/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.2395 - accuracy: 0.9300 - val_loss: 0.1501 - val_accuracy: 0.9540
# Epoch 4/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.2160 - accuracy: 0.9356 - val_loss: 0.1363 - val_accuracy: 0.9605
# Epoch 5/30
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.1981 - accuracy: 0.9409 - val_loss: 0.1228 - val_accuracy: 0.9633
# Epoch 6/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.1864 - accuracy: 0.9453 - val_loss: 0.1188 - val_accuracy: 0.9635
# Epoch 7/30
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.1767 - accuracy: 0.9475 - val_loss: 0.1062 - val_accuracy: 0.9689
# Epoch 8/30
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.1697 - accuracy: 0.9500 - val_loss: 0.1035 - val_accuracy: 0.9689
# Epoch 9/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.1628 - accuracy: 0.9501 - val_loss: 0.0999 - val_accuracy: 0.9686
# Epoch 10/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.1555 - accuracy: 0.9542 - val_loss: 0.0965 - val_accuracy: 0.9713
# Epoch 11/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.1506 - accuracy: 0.9552 - val_loss: 0.0989 - val_accuracy: 0.9694
# Epoch 12/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.1436 - accuracy: 0.9574 - val_loss: 0.0959 - val_accuracy: 0.9710
# Epoch 13/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1380 - accuracy: 0.9590 - val_loss: 0.0946 - val_accuracy: 0.9720
# Epoch 14/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1366 - accuracy: 0.9596 - val_loss: 0.0845 - val_accuracy: 0.9748
# Epoch 15/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1303 - accuracy: 0.9611 - val_loss: 0.0847 - val_accuracy: 0.9742
# Epoch 16/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1291 - accuracy: 0.9608 - val_loss: 0.0790 - val_accuracy: 0.9750
# Epoch 17/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1235 - accuracy: 0.9628 - val_loss: 0.0877 - val_accuracy: 0.9753
# Epoch 18/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1235 - accuracy: 0.9622 - val_loss: 0.0844 - val_accuracy: 0.9759
# Epoch 19/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1248 - accuracy: 0.9615 - val_loss: 0.0848 - val_accuracy: 0.9741
# Epoch 20/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1194 - accuracy: 0.9642 - val_loss: 0.0854 - val_accuracy: 0.9753
# Epoch 21/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1166 - accuracy: 0.9650 - val_loss: 0.0822 - val_accuracy: 0.9745
# Epoch 22/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1131 - accuracy: 0.9659 - val_loss: 0.0831 - val_accuracy: 0.9755
# Epoch 23/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1146 - accuracy: 0.9651 - val_loss: 0.0780 - val_accuracy: 0.9763
# Epoch 24/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.1090 - accuracy: 0.9660 - val_loss: 0.0834 - val_accuracy: 0.9771
# Epoch 25/30
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.1103 - accuracy: 0.9666 - val_loss: 0.0827 - val_accuracy: 0.9756
# Epoch 26/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1092 - accuracy: 0.9671 - val_loss: 0.0813 - val_accuracy: 0.9775
# Epoch 27/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1066 - accuracy: 0.9678 - val_loss: 0.0773 - val_accuracy: 0.9791
# Epoch 28/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1071 - accuracy: 0.9679 - val_loss: 0.0818 - val_accuracy: 0.9761
# Epoch 29/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1025 - accuracy: 0.9692 - val_loss: 0.0833 - val_accuracy: 0.9763
# Epoch 30/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1006 - accuracy: 0.9689 - val_loss: 0.0824 - val_accuracy: 0.9773
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.2552 - accuracy: 0.9234 - val_loss: 0.1505 - val_accuracy: 0.9542
# Epoch 2/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.1163 - accuracy: 0.9642 - val_loss: 0.1073 - val_accuracy: 0.9664
# Epoch 3/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0803 - accuracy: 0.9748 - val_loss: 0.0824 - val_accuracy: 0.9727
# Epoch 4/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0590 - accuracy: 0.9818 - val_loss: 0.0696 - val_accuracy: 0.9767
# Epoch 5/30
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.0445 - accuracy: 0.9860 - val_loss: 0.0809 - val_accuracy: 0.9746
# Epoch 6/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0333 - accuracy: 0.9898 - val_loss: 0.0641 - val_accuracy: 0.9796
# Epoch 7/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0253 - accuracy: 0.9929 - val_loss: 0.0659 - val_accuracy: 0.9794
# Epoch 8/30
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.0200 - accuracy: 0.9943 - val_loss: 0.0660 - val_accuracy: 0.9791
# Epoch 9/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 0.0141 - accuracy: 0.9964 - val_loss: 0.0726 - val_accuracy: 0.9776
# Epoch 10/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0093 - accuracy: 0.9982 - val_loss: 0.0667 - val_accuracy: 0.9803
# Epoch 11/30
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.0062 - accuracy: 0.9991 - val_loss: 0.0621 - val_accuracy: 0.9812
# Epoch 12/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0044 - accuracy: 0.9995 - val_loss: 0.0609 - val_accuracy: 0.9810
# Epoch 13/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0678 - val_accuracy: 0.9800
# Epoch 14/30
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0617 - val_accuracy: 0.9812
# Epoch 15/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9812
# Epoch 16/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.0619 - val_accuracy: 0.9814
# Epoch 17/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0640 - val_accuracy: 0.9809
# Epoch 18/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9810
# Epoch 19/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0634 - val_accuracy: 0.9812
# Epoch 20/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 9.6362e-04 - accuracy: 1.0000 - val_loss: 0.0637 - val_accuracy: 0.9814
# Epoch 21/30
# 60000/60000 [==============================] - 3s 56us/sample - loss: 8.7674e-04 - accuracy: 1.0000 - val_loss: 0.0644 - val_accuracy: 0.9813
# Epoch 22/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 8.1160e-04 - accuracy: 1.0000 - val_loss: 0.0639 - val_accuracy: 0.9815
# Epoch 23/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 7.5143e-04 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9815
# Epoch 24/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 7.0258e-04 - accuracy: 1.0000 - val_loss: 0.0646 - val_accuracy: 0.9814
# Epoch 25/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 6.5583e-04 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9816
# Epoch 26/30
# 60000/60000 [==============================] - 3s 52us/sample - loss: 6.2045e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9808
# Epoch 27/30
# 60000/60000 [==============================] - 3s 55us/sample - loss: 5.8468e-04 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9817
# Epoch 28/30
# 60000/60000 [==============================] - 3s 51us/sample - loss: 5.5141e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9814
# Epoch 29/30
# 60000/60000 [==============================] - 3s 53us/sample - loss: 5.2383e-04 - accuracy: 1.0000 - val_loss: 0.0660 - val_accuracy: 0.9818
# Epoch 30/30
# 60000/60000 [==============================] - 3s 57us/sample - loss: 4.9737e-04 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9818

# %%
# 画出model1验证集准确率曲线图
plt.plot(np.arange(epochs),history1.history['val_accuracy'],c='b',label='Dropout')
# 画出model2验证集准确率曲线图
plt.plot(np.arange(epochs),history2.history['val_accuracy'],c='y',label='FC')
# 图例
plt.legend()
# x坐标描述
plt.xlabel('epochs')
# y坐标描述
plt.ylabel('accuracy')
# 显示图像
plt.show()
