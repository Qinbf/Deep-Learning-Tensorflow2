# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,Dense,Dropout,Conv2D,MaxPool2D,Flatten,GlobalAvgPool2D,BatchNormalization,Activation,Add,ZeroPadding2D,Multiply
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import Model
# Out:
# D:\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# D:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# D:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# 类别数
num_classes = 17
# 批次大小
batch_size = 32
# 周期数
epochs = 100
# 图片大小
image_size = 224

# %%
# 训练集数据进行数据增强
train_datagen = ImageDataGenerator(
    rotation_range = 20,     # 随机旋转度数
    width_shift_range = 0.1, # 随机水平平移
    height_shift_range = 0.1,# 随机竖直平移
    rescale = 1/255,         # 数据归一化
    shear_range = 10,       # 随机错切变换
    zoom_range = 0.1,        # 随机放大
    horizontal_flip = True,  # 水平翻转
    brightness_range=(0.7, 1.3), # 亮度变化
    fill_mode = 'nearest',   # 填充方式
) 
# 测试集数据只需要归一化就可以
test_datagen = ImageDataGenerator(
    rescale = 1/255,         # 数据归一化
)

# %%
# 训练集数据生成器，可以在训练时自动产生数据进行训练
# 从'data/train'获得训练集数据
# 获得数据后会把图片resize为image_size×image_size的大小
# generator每次会产生batch_size个数据
train_generator = train_datagen.flow_from_directory(
    'data/train',
    target_size=(image_size,image_size),
    batch_size=batch_size,
    )

# 测试集数据生成器
test_generator = test_datagen.flow_from_directory(
    'data/test',
    target_size=(image_size,image_size),
    batch_size=batch_size,
    )
# Out:
# Found 1088 images belonging to 17 classes.
# Found 272 images belonging to 17 classes.

# %%
# 字典的键为17个文件夹的名字，值为对应的分类编号
train_generator.class_indices
# Out:
# {'flower0': 0,
#  'flower1': 1,
#  'flower10': 2,
#  'flower11': 3,
#  'flower12': 4,
#  'flower13': 5,
#  'flower14': 6,
#  'flower15': 7,
#  'flower16': 8,
#  'flower2': 9,
#  'flower3': 10,
#  'flower4': 11,
#  'flower5': 12,
#  'flower6': 13,
#  'flower7': 14,
#  'flower8': 15,
#  'flower9': 16}

# %%
# SE模块
def ChannelSE(input_tensor, reduction=16):
    # 获得信号通道数
    channels = input_tensor.shape[-1]
    # SE模块
    x = GlobalAvgPool2D()(input_tensor)
    # 把2维数据再变成4维(?,1,1,?)
    x = x[:, None, None, :]
    # 卷积替代全连接层
    x = Conv2D(filters=channels//reduction,kernel_size=1,strides=1)(x)
    x = Activation('relu')(x)
    x = Conv2D(filters=channels,kernel_size=1,strides=1)(x)
    x = Activation('sigmoid')(x)
    x = Multiply()([input_tensor, x])
    return x


# 定义残差单元
def block(x, filters, strides=1, conv_shortcut=True, reduction=16): 
    # projection shortcut
    if conv_shortcut == True:
        shortcut = Conv2D(filters*4,kernel_size=1,strides=strides,padding='valid')(x)
        # epsilon为BN公式中防止分母为零的值
        shortcut = BatchNormalization(epsilon=1.001e-5)(shortcut)
    else:
        # identity_shortcut
        shortcut = x
    # 3个卷积层
    x = Conv2D(filters=filters,kernel_size=1,strides=strides,padding='valid')(x)
    x = BatchNormalization(epsilon=1.001e-5)(x)
    x = Activation('relu')(x)
 
    x = Conv2D(filters=filters,kernel_size=3,strides=1,padding='same')(x)
    x = BatchNormalization(epsilon=1.001e-5)(x)
    x = Activation('relu')(x)
 
    x = Conv2D(filters=filters*4,kernel_size=1,strides=1,padding='valid')(x)
    x = BatchNormalization(epsilon=1.001e-5)(x)
    
    # SE模块
    x = ChannelSE(x, reduction=reduction)
 
    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# 堆叠残差单元
def stack(x, filters, blocks, strides):
    x = block(x, filters, strides=strides)
    for i in range(blocks-1):
        x = block(x, filters, conv_shortcut=False)
    return x
    
# 定义SE-ResNet50
inputs = Input(shape=(image_size,image_size,3))
# 填充3圈0，填充后图像从224×224变成230×230
x = ZeroPadding2D((3, 3))(inputs)
x= Conv2D(filters=64,kernel_size=7,strides=2,padding='valid')(x)
x = BatchNormalization(epsilon=1.001e-5)(x)
x = Activation('relu')(x)
# 填充1圈0
x = ZeroPadding2D((1, 1))(x)
x = MaxPool2D(pool_size=3,strides=2,padding='valid')(x)
# 堆叠残差结构
# blocks表示堆叠数量
x = stack(x, filters=64, blocks=3, strides=1)
x = stack(x, filters=128, blocks=4, strides=2)
x = stack(x, filters=256, blocks=6, strides=2)
x = stack(x, filters=512, blocks=3, strides=2)
# 根据特征图大小进行平均池化，池化后得到2维数据
x = GlobalAvgPool2D()(x)
x = Dense(num_classes, activation='softmax')(x)
# 定义模型
model = Model(inputs=inputs,outputs=x)

# %%
# 学习率调节函数，逐渐减小学习率
def adjust_learning_rate(epoch):
    # 前40周期
    if epoch<=40:
        lr = 1e-4
    # 前40到80周期
    elif epoch>40 and epoch<=80:
        lr = 1e-5
    # 80到100周期
    else:
        lr = 1e-6
    return lr

# %%
# 定义优化器
adam = Adam(lr=1e-4)

# 定义学习率衰减策略
callbacks = []
callbacks.append(LearningRateScheduler(adjust_learning_rate))

# 定义优化器，loss function，训练过程中计算准确率
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])

# Tensorflow2.1版本之前可以使用fit_generator训练模型
# history = model.fit_generator(train_generator,steps_per_epoch=len(train_generator),epochs=epochs,validation_data=test_generator,validation_steps=len(test_generator))

# Tensorflow2.1版本(包括2.1)之后可以直接使用fit训练模型
history = model.fit(x=train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0320 10:01:23.518372 11692 data_adapter.py:1091] sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# W0320 10:01:23.822364 11692 data_adapter.py:1091] sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 34 steps, validate for 9 steps
# Epoch 1/100
# 34/34 [==============================] - 27s 786ms/step - loss: 2.4803 - accuracy: 0.2114 - val_loss: 2.8556 - val_accuracy: 0.0588
# Epoch 2/100
# 34/34 [==============================] - 14s 401ms/step - loss: 1.8287 - accuracy: 0.4017 - val_loss: 2.9926 - val_accuracy: 0.0588
# Epoch 3/100
# 34/34 [==============================] - 14s 399ms/step - loss: 1.5381 - accuracy: 0.4908 - val_loss: 3.2226 - val_accuracy: 0.0588
# Epoch 4/100
ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 1.0398 - val_accuracy: 0.8088
# Epoch 45/100
# 34/34 [==============================] - 14s 417ms/step - loss: 0.0186 - accuracy: 0.9982 - val_loss: 1.0536 - val_accuracy: 0.8088
# Epoch 46/100
# 34/34 [==============================] - 14s 417ms/step - loss: 0.0141 - accuracy: 0.9982 - val_loss: 1.0387 - val_accuracy: 0.8088
# Epoch 47/100
# 34/34 [==============================] - 14s 421ms/step - loss: 0.0123 - accuracy: 0.9991 - val_loss: 1.0264 - val_accuracy: 0.8015
# Epoch 48/100
# 34/34 [==============================] - 14s 420ms/step - loss: 0.0128 - accuracy: 0.9991 - val_loss: 1.0211 - val_accuracy: 0.8051
# Epoch 49/100
# 34/34 [==============================] - 14s 411ms/step - loss: 0.0126 - accuracy: 0.9991 - val_loss: 1.0292 - val_accuracy: 0.7941
# Epoch 50/100
# 34/34 [==============================] - 14s 411ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.0159 - val_accuracy: 0.8051
# Epoch 51/100
# 34/34 [==============================] - 14s 406ms/step - loss: 0.0127 - accuracy: 0.9982 - val_loss: 0.9917 - val_accuracy: 0.8162
# Epoch 52/100
# 34/34 [==============================] - 14s 412ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 1.0057 - val_accuracy: 0.7941
# Epoch 53/100
# 34/34 [==============================] - 14s 409ms/step - loss: 0.0098 - accuracy: 0.9982 - val_loss: 0.9697 - val_accuracy: 0.8015
# Epoch 54/100
# 34/34 [==============================] - 14s 403ms/step - loss: 0.0087 - accuracy: 0.9991 - val_loss: 1.0069 - val_accuracy: 0.7978
# Epoch 55/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.0752 - val_accuracy: 0.7941
# Epoch 56/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.0503 - val_accuracy: 0.7904
# Epoch 57/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0089 - accuracy: 0.9991 - val_loss: 1.0165 - val_accuracy: 0.7978
# Epoch 58/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 1.0191 - val_accuracy: 0.7978
# Epoch 59/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.0002 - val_accuracy: 0.7941
# Epoch 60/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0077 - accuracy: 0.9991 - val_loss: 1.0496 - val_accuracy: 0.7941
# Epoch 61/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0093 - accuracy: 0.9991 - val_loss: 1.0879 - val_accuracy: 0.7868
# Epoch 62/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 1.0713 - val_accuracy: 0.7904
# Epoch 63/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.0323 - val_accuracy: 0.8051
# Epoch 64/100
# 34/34 [==============================] - 13s 397ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 1.0104 - val_accuracy: 0.8015
# Epoch 65/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.0083 - accuracy: 0.9991 - val_loss: 1.0080 - val_accuracy: 0.8015
# Epoch 66/100
# 34/34 [==============================] - 13s 397ms/step - loss: 0.0105 - accuracy: 0.9972 - val_loss: 1.0140 - val_accuracy: 0.8015
# Epoch 67/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 1.0364 - val_accuracy: 0.7904
# Epoch 68/100
# 34/34 [==============================] - 14s 400ms/step - loss: 0.0082 - accuracy: 0.9991 - val_loss: 1.0044 - val_accuracy: 0.8088
# Epoch 69/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.9876 - val_accuracy: 0.8088
# Epoch 70/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 1.0156 - val_accuracy: 0.8015
# Epoch 71/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.0326 - val_accuracy: 0.8051
# Epoch 72/100
# 34/34 [==============================] - 13s 397ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.0176 - val_accuracy: 0.8051
# Epoch 73/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 1.0129 - val_accuracy: 0.8051
# Epoch 74/100
# 34/34 [==============================] - 13s 397ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.0217 - val_accuracy: 0.8015
# Epoch 75/100
# 34/34 [==============================] - 13s 397ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.0192 - val_accuracy: 0.8088
# Epoch 76/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 1.0226 - val_accuracy: 0.8051
# Epoch 77/100
# 34/34 [==============================] - 14s 403ms/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 1.0215 - val_accuracy: 0.8051
# Epoch 78/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.0082 - val_accuracy: 0.8125
# Epoch 79/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.0065 - accuracy: 0.9991 - val_loss: 0.9762 - val_accuracy: 0.8088
# Epoch 80/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.9979 - val_accuracy: 0.8088
# Epoch 81/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0108 - val_accuracy: 0.8015
# Epoch 82/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.0160 - val_accuracy: 0.8051
# Epoch 83/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0064 - accuracy: 0.9991 - val_loss: 1.0217 - val_accuracy: 0.8088
# Epoch 84/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0290 - val_accuracy: 0.8088
# Epoch 85/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0286 - val_accuracy: 0.8088
# Epoch 86/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.0285 - val_accuracy: 0.8088
# Epoch 87/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.0274 - val_accuracy: 0.8088
# Epoch 88/100
# 34/34 [==============================] - 14s 401ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.0283 - val_accuracy: 0.8088
# Epoch 89/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.0304 - val_accuracy: 0.8051
# Epoch 90/100
# 34/34 [==============================] - 14s 397ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0311 - val_accuracy: 0.8088
# Epoch 91/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 1.0328 - val_accuracy: 0.8051
# Epoch 92/100
# 34/34 [==============================] - 13s 396ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.0318 - val_accuracy: 0.8088
# Epoch 93/100
# 34/34 [==============================] - 14s 398ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.0318 - val_accuracy: 0.8051
# Epoch 94/100
# 34/34 [==============================] - 14s 399ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.0353 - val_accuracy: 0.8051
# Epoch 95/100
# 34/34 [==============================] - 14s 403ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.0342 - val_accuracy: 0.8088
# Epoch 96/100
# 34/34 [==============================] - 14s 408ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.0335 - val_accuracy: 0.8051
# Epoch 97/100
# 34/34 [==============================] - 14s 407ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.0341 - val_accuracy: 0.8051
# Epoch 98/100
# 34/34 [==============================] - 14s 408ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.0338 - val_accuracy: 0.8088
# Epoch 99/100
# 34/34 [==============================] - 14s 406ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0369 - val_accuracy: 0.8088
# Epoch 100/100
# 34/34 [==============================] - 14s 407ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.0355 - val_accuracy: 0.8088

# %%
# 画出训练集准确率曲线图
plt.plot(np.arange(epochs),history.history['accuracy'],c='b',label='train_accuracy')
# 画出验证集准确率曲线图
plt.plot(np.arange(epochs),history.history['val_accuracy'],c='y',label='val_accuracy')
# 图例
plt.legend()
# x坐标描述
plt.xlabel('epochs')
# y坐标描述
plt.ylabel('accuracy')
# 显示图像
plt.show()
# 模型保存
model.save('SE-ResNet50.h5')
