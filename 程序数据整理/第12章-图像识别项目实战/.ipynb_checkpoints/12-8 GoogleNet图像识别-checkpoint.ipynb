# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,Dense,Dropout,Conv2D,MaxPool2D,Flatten,AvgPool2D,concatenate
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.models import Model
# Out:
# D:\Anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# D:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.IPBC74C7KURV7CB2PKT5Z5FNR3SIBV4J.gfortran-win_amd64.dll
# D:\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
# 类别数
num_classes = 17
# 批次大小
batch_size = 32
# 周期数
epochs = 100
# 图片大小
image_size = 224

# %%
# 训练集数据进行数据增强
train_datagen = ImageDataGenerator(
    rotation_range = 20,     # 随机旋转度数
    width_shift_range = 0.1, # 随机水平平移
    height_shift_range = 0.1,# 随机竖直平移
    rescale = 1/255,         # 数据归一化
    shear_range = 10,       # 随机错切变换
    zoom_range = 0.1,        # 随机放大
    horizontal_flip = True,  # 水平翻转
    brightness_range=(0.7, 1.3), # 亮度变化
    fill_mode = 'nearest',   # 填充方式
) 
# 测试集数据只需要归一化就可以
test_datagen = ImageDataGenerator(
    rescale = 1/255,         # 数据归一化
)

# %%
# 训练集数据生成器，可以在训练时自动产生数据进行训练
# 从'data/train'获得训练集数据
# 获得数据后会把图片resize为image_size×image_size的大小
# generator每次会产生batch_size个数据
train_generator = train_datagen.flow_from_directory(
    'data/train',
    target_size=(image_size,image_size),
    batch_size=batch_size,
    )

# 测试集数据生成器
test_generator = test_datagen.flow_from_directory(
    'data/test',
    target_size=(image_size,image_size),
    batch_size=batch_size,
    )
# Out:
# Found 1088 images belonging to 17 classes.
# Found 272 images belonging to 17 classes.

# %%
# 字典的键为17个文件夹的名字，值为对应的分类编号
# train_generator.class_indices

# %%
# 定义Inception结构
def Inception(x,filters):
    tower_1 = Conv2D(filters=filters[0],kernel_size=1,strides=1,padding='same',activation='relu')(x)
    tower_2 = Conv2D(filters=filters[1],kernel_size=1,strides=1,padding='same',activation='relu')(x)
    tower_2 = Conv2D(filters=filters[2],kernel_size=3,strides=1,padding='same',activation='relu')(tower_2)
    tower_3 = Conv2D(filters=filters[3],kernel_size=1,strides=1,padding='same',activation='relu')(x)
    tower_3 = Conv2D(filters=filters[4],kernel_size=5,strides=1,padding='same',activation='relu')(tower_3)
    pooling = MaxPool2D(pool_size=3,strides=1,padding='same')(x)
    pooling = Conv2D(filters=filters[5],kernel_size=1,strides=1,padding='same',activation='relu')(pooling)
    x = concatenate([tower_1,tower_2,tower_3,pooling],axis=3)
    return x
    
# 定义GoogleNet模型
model_input = Input(shape=(image_size,image_size,3))
x = Conv2D(filters=64,kernel_size=7,strides=2,padding='same',activation='relu')(model_input)
x = MaxPool2D(pool_size=3,strides=2,padding='same')(x)
x = Conv2D(filters=64,kernel_size=1,strides=1,padding='same',activation='relu')(x)
x = Conv2D(filters=192,kernel_size=3,strides=1,padding='same',activation='relu')(x)
x = MaxPool2D(pool_size=3,strides=2,padding='same')(x)
x = Inception(x,[64,96,128,16,32,32])
x = Inception(x,[128,128,192,32,96,64])
x = MaxPool2D(pool_size=3,strides=2,padding='same')(x)
x = Inception(x,[192,96,208,16,48,64])
x = Inception(x,[160,112,224,24,64,64])
x = Inception(x,[128,128,256,24,64,64])
x = Inception(x,[112,144,288,32,64,64])
x = Inception(x,[256,160,320,32,128,128])
x = MaxPool2D(pool_size=3,strides=2,padding='same')(x)
x = Inception(x,[256,160,320,32,128,128])
x = Inception(x,[384,192,384,48,128,128])
x = AvgPool2D(pool_size=7,strides=7,padding='same')(x)
x = Flatten()(x)
x = Dropout(0.4)(x)
x = Dense(num_classes,activation='softmax')(x)

model = Model(inputs=model_input,outputs=x)

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 56, 56, 64)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 56, 56, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 56, 56, 192)  110784      conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 96)   18528       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 16)   3088        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 64)   12352       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 256)  0           conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 32)   8224        concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 256)  0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 128)  32896       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 192)  221376      conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 480)  0           conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 480)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 96)   46176       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 16)   7696        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 192)  92352       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 14, 512)  0           conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 160)  82080       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           conv2d_21[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 128)  65664       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 512)  0           conv2d_27[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 144)  73872       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 32)   16416       concatenate_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 112)  57456       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 528)  0           conv2d_33[0][0]
#                                                                  conv2d_35[0][0]
#                                                                  conv2d_37[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 160)  84640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 32)   16928       concatenate_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 528)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 256)  135424      concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 832)  0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 160)    133280      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 32)     26656       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 7, 7, 832)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 256)    213248      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 7, 7, 832)    0           conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 192)    159936      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 48)     39984       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 7, 7, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 384)    319872      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 1024)   0           conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 1024)   0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1024)         0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1024)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 17)           17425       dropout[0][0]
# ==================================================================================================
# Total params: 5,990,977
# Trainable params: 5,990,977
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 学习率调节函数，逐渐减小学习率
def adjust_learning_rate(epoch):
    # 前40周期
    if epoch<=40:
        lr = 2e-4
    # 前40到80周期
    elif epoch>40 and epoch<=80:
        lr = 2e-5
    # 80到100周期
    else:
        lr = 2e-6
    return lr

# %%
# 定义优化器
adam = Adam(lr=2e-4)

# 定义学习率衰减策略
callbacks = []
callbacks.append(LearningRateScheduler(adjust_learning_rate))

# 定义优化器，loss function，训练过程中计算准确率
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])

# Tensorflow2.1版本之前可以使用fit_generator训练模型
# history = model.fit_generator(train_generator,steps_per_epoch=len(train_generator),epochs=epochs,validation_data=test_generator,validation_steps=len(test_generator))

# Tensorflow2.1版本(包括2.1)之后可以直接使用fit训练模型
history = model.fit(x=train_generator,epochs=epochs,validation_data=test_generator,callbacks=callbacks)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0317 11:47:38.489838  7160 data_adapter.py:1091] sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# W0317 11:47:38.632456  7160 data_adapter.py:1091] sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 34 steps, validate for 9 steps
# Epoch 1/100
# 34/34 [==============================] - 16s 477ms/step - loss: 2.7764 - accuracy: 0.0699 - val_loss: 2.5863 - val_accuracy: 0.1140
# Epoch 2/100
# 34/34 [==============================] - 13s 392ms/step - loss: 2.4651 - accuracy: 0.1360 - val_loss: 2.3358 - val_accuracy: 0.1471
# Epoch 3/100
# 34/34 [==============================] - 13s 387ms/step - loss: 2.3471 - accuracy: 0.1526 - val_loss: 2.2486 - val_accuracy: 0.1985
# Epoch 4/100
# 34/34 [==============================] - 13s 387ms/step - loss: 2.2225 - accuracy: 0.1857 - val_loss: 2.1144 - val_accuracy: 0.2721
# Epoch 5/100
# 34/34 [==============================] - 13s 387ms/step - loss: 2.1539 - accuracy: 0.1994 - val_loss: 1.9740 - val_accuracy: 0.2757
# Epoch 6/100
# 34/34 [==============================] - 13s 388ms/step - loss: 2.1089 - accuracy: 0.2298 - val_loss: 2.0747 - val_accuracy: 0.2132
# Epoch 7/100
# 34/34 [==============================] - 13s 387ms/step - loss: 2.1002 - accuracy: 0.2233 - val_loss: 1.8305 - val_accuracy: 0.2978
# Epoch 8/100
# 34/34 [==============================] - 13s 387ms/step - loss: 2.0401 - accuracy: 0.2390 - val_loss: 1.9040 - val_accuracy: 0.3493
# Epoch 9/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.9672 - accuracy: 0.2638 - val_loss: 1.7626 - val_accuracy: 0.3566
# Epoch 10/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.8572 - accuracy: 0.3051 - val_loss: 1.6715 - val_accuracy: 0.3419
# Epoch 11/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.7683 - accuracy: 0.3419 - val_loss: 1.6672 - val_accuracy: 0.4044
# Epoch 12/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.7291 - accuracy: 0.3575 - val_loss: 1.6954 - val_accuracy: 0.3750
# Epoch 13/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.7273 - accuracy: 0.3594 - val_loss: 1.5371 - val_accuracy: 0.4265
# Epoch 14/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.6529 - accuracy: 0.3906 - val_loss: 1.4626 - val_accuracy: 0.5110
# Epoch 15/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.4849 - accuracy: 0.4421 - val_loss: 1.3360 - val_accuracy: 0.5257
# Epoch 16/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.5250 - accuracy: 0.4357 - val_loss: 1.3884 - val_accuracy: 0.4926
# Epoch 17/100
# 34/34 [==============================] - 13s 389ms/step - loss: 1.4940 - accuracy: 0.4614 - val_loss: 1.3283 - val_accuracy: 0.5551
# Epoch 18/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.3300 - accuracy: 0.5119 - val_loss: 1.2885 - val_accuracy: 0.5368
# Epoch 19/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.2813 - accuracy: 0.5294 - val_loss: 1.1941 - val_accuracy: 0.5515
# Epoch 20/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.2802 - accuracy: 0.5202 - val_loss: 1.1804 - val_accuracy: 0.5846
# Epoch 21/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.2124 - accuracy: 0.5561 - val_loss: 1.1955 - val_accuracy: 0.5882
# Epoch 22/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.1624 - accuracy: 0.5836 - val_loss: 1.1563 - val_accuracy: 0.5993
# Epoch 23/100
# 34/34 [==============================] - 13s 386ms/step - loss: 1.0556 - accuracy: 0.6158 - val_loss: 1.1083 - val_accuracy: 0.5993
# Epoch 24/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.0917 - accuracy: 0.6167 - val_loss: 1.1132 - val_accuracy: 0.6434
# Epoch 25/100
# 34/34 [==============================] - 13s 387ms/step - loss: 1.0335 - accuracy: 0.6443 - val_loss: 1.0811 - val_accuracy: 0.6618
# Epoch 26/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.0330 - accuracy: 0.6489 - val_loss: 0.9272 - val_accuracy: 0.7169
# Epoch 27/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.9875 - accuracy: 0.6608 - val_loss: 0.9630 - val_accuracy: 0.6801
# Epoch 28/100
# 34/34 [==============================] - 13s 388ms/step - loss: 1.0306 - accuracy: 0.6415 - val_loss: 1.1063 - val_accuracy: 0.6507
# Epoch 29/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.9368 - accuracy: 0.6728 - val_loss: 0.8747 - val_accuracy: 0.7243
# Epoch 30/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.8717 - accuracy: 0.6866 - val_loss: 0.9082 - val_accuracy: 0.6912
# Epoch 31/100
# 34/34 [==============================] - 13s 386ms/step - loss: 0.9028 - accuracy: 0.6811 - val_loss: 0.8890 - val_accuracy: 0.7243
# Epoch 32/100
# 34/34 [==============================] - 13s 386ms/step - loss: 0.8331 - accuracy: 0.7013 - val_loss: 0.7801 - val_accuracy: 0.7537
# Epoch 33/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.7572 - accuracy: 0.7206 - val_loss: 0.8882 - val_accuracy: 0.7316
# Epoch 34/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.7290 - accuracy: 0.7426 - val_loss: 0.8881 - val_accuracy: 0.7316
# Epoch 35/100
# 34/34 [==============================] - 13s 389ms/step - loss: 0.8314 - accuracy: 0.7059 - val_loss: 0.8533 - val_accuracy: 0.7059
# Epoch 36/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.7486 - accuracy: 0.7408 - val_loss: 0.8739 - val_accuracy: 0.7059
# Epoch 37/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.7438 - accuracy: 0.7298 - val_loss: 0.9192 - val_accuracy: 0.7169
# Epoch 38/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.6964 - accuracy: 0.7574 - val_loss: 1.0928 - val_accuracy: 0.6875
# Epoch 39/100
# 34/34 [==============================] - 13s 385ms/step - loss: 0.7031 - accuracy: 0.7546 - val_loss: 0.9242 - val_accuracy: 0.7610
# Epoch 40/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.6946 - accuracy: 0.7656 - val_loss: 0.7096 - val_accuracy: 0.7353
# Epoch 41/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.6171 - accuracy: 0.7914 - val_loss: 0.7489 - val_accuracy: 0.7757
# Epoch 42/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.4709 - accuracy: 0.8327 - val_loss: 0.6684 - val_accuracy: 0.7794
# Epoch 43/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.4268 - accuracy: 0.8447 - val_loss: 0.6714 - val_accuracy: 0.7941
# Epoch 44/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.3927 - accuracy: 0.8612 - val_loss: 0.6769 - val_accuracy: 0.7868
# Epoch 45/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3652 - accuracy: 0.8750 - val_loss: 0.6938 - val_accuracy: 0.8015
# Epoch 46/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3756 - accuracy: 0.8741 - val_loss: 0.6884 - val_accuracy: 0.8015
# Epoch 47/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3594 - accuracy: 0.8778 - val_loss: 0.7046 - val_accuracy: 0.7868
# Epoch 48/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3643 - accuracy: 0.8842 - val_loss: 0.7149 - val_accuracy: 0.7941
# Epoch 49/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3377 - accuracy: 0.8879 - val_loss: 0.7280 - val_accuracy: 0.7941
# Epoch 50/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3366 - accuracy: 0.8879 - val_loss: 0.7064 - val_accuracy: 0.7978
# Epoch 51/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3442 - accuracy: 0.8796 - val_loss: 0.7363 - val_accuracy: 0.7868
# Epoch 52/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3465 - accuracy: 0.8897 - val_loss: 0.7394 - val_accuracy: 0.7941
# Epoch 53/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3349 - accuracy: 0.8869 - val_loss: 0.7165 - val_accuracy: 0.8015
# Epoch 54/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3296 - accuracy: 0.8851 - val_loss: 0.7077 - val_accuracy: 0.7904
# Epoch 55/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.3011 - accuracy: 0.8943 - val_loss: 0.7614 - val_accuracy: 0.7978
# Epoch 56/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.3097 - accuracy: 0.8915 - val_loss: 0.7365 - val_accuracy: 0.7978
# Epoch 57/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2827 - accuracy: 0.9035 - val_loss: 0.7124 - val_accuracy: 0.7978
# Epoch 58/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.3272 - accuracy: 0.8833 - val_loss: 0.7641 - val_accuracy: 0.7794
# Epoch 59/100
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2804 - accuracy: 0.9072 - val_loss: 0.7592 - val_accuracy: 0.7868
# Epoch 60/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.3052 - accuracy: 0.8915 - val_loss: 0.7364 - val_accuracy: 0.7978
# Epoch 61/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2830 - accuracy: 0.9007 - val_loss: 0.7390 - val_accuracy: 0.8051
# Epoch 62/100
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2766 - accuracy: 0.9026 - val_loss: 0.7535 - val_accuracy: 0.7978
# Epoch 63/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2571 - accuracy: 0.9062 - val_loss: 0.7547 - val_accuracy: 0.8015
# Epoch 64/100
# 34/34 [==============================] - 13s 389ms/step - loss: 0.2691 - accuracy: 0.9127 - val_loss: 0.8095 - val_accuracy: 0.7868
# Epoch 65/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2730 - accuracy: 0.9007 - val_loss: 0.7659 - val_accuracy: 0.7941
# Epoch 66/100
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2748 - accuracy: 0.9081 - val_loss: 0.7775 - val_accuracy: 0.7904
# Epoch 67/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2591 - accuracy: 0.9136 - val_loss: 0.7688 - val_accuracy: 0.7868
# Epoch 68/100
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2366 - accuracy: 0.9182 - val_loss: 0.7886 - val_accuracy: 0.7831
# Epoch 69/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2400 - accuracy: 0.9164 - val_loss: 0.8707 - val_accuracy: 0.7684
# Epoch 70/100
# 34/34 [==============================] - 13s 386ms/step - loss: 0.2501 - accuracy: 0.9164 - val_loss: 0.8119 - val_accuracy: 0.7831
# Epoch 71/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2257 - accuracy: 0.9200 - val_loss: 0.7637 - val_accuracy: 0.8051
# Epoch 72/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2420 - accuracy: 0.9164 - val_loss: 0.7910 - val_accuracy: 0.8015
# Epoch 73/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2290 - accuracy: 0.9200 - val_loss: 0.7748 - val_accuracy: 0.7684
# Epoch 74/100
# 34/34 [==============================] - 13s 387ms/step - loss: 0.2301 - accuracy: 0.9219 - val_loss: 0.7696 - val_accuracy: 0.7904
# Epoch 75/100
# 34/34 [==============================] - 13s 389ms/step - loss: 0.2203 - accuracy: 0.9246 - val_loss: 0.8404 - val_accuracy: 0.8015
# Epoch 76/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2100 - accuracy: 0.9292 - val_loss: 0.8549 - val_accuracy: 0.8051
# Epoch 77/100
# 34/34 [==============================] - 13s 388ms/step - loss: 0.2265 - accuracy: 0.9246 - val_loss: 0.8236 - val_accuracy: 0.8088
# Epoch 78/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.2197 - accuracy: 0.9154 - val_loss: 0.8163 - val_accuracy: 0.7904
# Epoch 79/100
# 34/34 [==============================] - 13s 394ms/step - loss: 0.2036 - accuracy: 0.9311 - val_loss: 0.8318 - val_accuracy: 0.7904
# Epoch 80/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1866 - accuracy: 0.9347 - val_loss: 0.8401 - val_accuracy: 0.7978
# Epoch 81/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1876 - accuracy: 0.9357 - val_loss: 0.8301 - val_accuracy: 0.8015
# Epoch 82/100
# 34/34 [==============================] - 13s 394ms/step - loss: 0.1792 - accuracy: 0.9449 - val_loss: 0.8351 - val_accuracy: 0.7978
# Epoch 83/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1826 - accuracy: 0.9393 - val_loss: 0.8433 - val_accuracy: 0.7941
# Epoch 84/100
# 34/34 [==============================] - 13s 392ms/step - loss: 0.1698 - accuracy: 0.9421 - val_loss: 0.8309 - val_accuracy: 0.7941
# Epoch 85/100
# 34/34 [==============================] - 13s 391ms/step - loss: 0.1641 - accuracy: 0.9531 - val_loss: 0.8407 - val_accuracy: 0.7904
# Epoch 86/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1774 - accuracy: 0.9403 - val_loss: 0.8372 - val_accuracy: 0.7941
# Epoch 87/100
# 34/34 [==============================] - 13s 390ms/step - loss: 0.1592 - accuracy: 0.9467 - val_loss: 0.8449 - val_accuracy: 0.7868
# Epoch 88/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1596 - accuracy: 0.9430 - val_loss: 0.8455 - val_accuracy: 0.7868
# Epoch 89/100
# 34/34 [==============================] - 13s 394ms/step - loss: 0.1683 - accuracy: 0.9430 - val_loss: 0.8442 - val_accuracy: 0.7904
# Epoch 90/100
# 34/34 [==============================] - 13s 395ms/step - loss: 0.1681 - accuracy: 0.9375 - val_loss: 0.8552 - val_accuracy: 0.7868
# Epoch 91/100
# 34/34 [==============================] - 13s 394ms/step - loss: 0.1709 - accuracy: 0.9421 - val_loss: 0.8469 - val_accuracy: 0.7868
# Epoch 92/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1504 - accuracy: 0.9513 - val_loss: 0.8545 - val_accuracy: 0.7904
# Epoch 93/100
# 34/34 [==============================] - 13s 394ms/step - loss: 0.1817 - accuracy: 0.9357 - val_loss: 0.8474 - val_accuracy: 0.7831
# Epoch 94/100
# 34/34 [==============================] - 13s 391ms/step - loss: 0.1674 - accuracy: 0.9403 - val_loss: 0.8511 - val_accuracy: 0.7831
# Epoch 95/100
# 34/34 [==============================] - 13s 391ms/step - loss: 0.1581 - accuracy: 0.9485 - val_loss: 0.8584 - val_accuracy: 0.7831
# Epoch 96/100
# 34/34 [==============================] - 13s 395ms/step - loss: 0.1582 - accuracy: 0.9476 - val_loss: 0.8616 - val_accuracy: 0.7904
# Epoch 97/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1414 - accuracy: 0.9522 - val_loss: 0.8740 - val_accuracy: 0.7868
# Epoch 98/100
# 34/34 [==============================] - 13s 395ms/step - loss: 0.1579 - accuracy: 0.9412 - val_loss: 0.8721 - val_accuracy: 0.7831
# Epoch 99/100
# 34/34 [==============================] - 13s 395ms/step - loss: 0.1723 - accuracy: 0.9366 - val_loss: 0.8696 - val_accuracy: 0.7831
# Epoch 100/100
# 34/34 [==============================] - 13s 393ms/step - loss: 0.1641 - accuracy: 0.9430 - val_loss: 0.8596 - val_accuracy: 0.7904

# %%
# 画出训练集准确率曲线图
plt.plot(np.arange(epochs),history.history['accuracy'],c='b',label='train_accuracy')
# 画出验证集准确率曲线图
plt.plot(np.arange(epochs),history.history['val_accuracy'],c='y',label='val_accuracy')
# 图例
plt.legend()
# x坐标描述
plt.xlabel('epochs')
# y坐标描述
plt.ylabel('accuracy')
# 显示图像
plt.show()
# 模型保存
model.save('GoogleNet.h5')
